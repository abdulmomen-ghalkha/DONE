# %%
from utils.plot_utils import get_training_data_value, simple_read_data
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # MNIST IID

# %%
rs_train_acc_sop, rs_train_loss_sop, rs_glob_acc_sop = simple_read_data("Mnist_Sophia_0.01_(0.9, 0.95)_5.0_0.1_32u_64b_1_0_IID")
rs_train_acc_done, rs_train_loss_done, rs_glob_acc_done = simple_read_data("Mnist_DONE_1_0.01_1.0_0.001_32u_0b_40_0_IID")
#("Mnist_DONE_1_0.008_1.0_0.001_32u_0b_40_0")
rs_train_acc_gd, rs_train_loss_gd, rs_glob_acc_gd = simple_read_data("Mnist_FedAvg_0.008_0.03_20.0_0.001_32u_64b_10_0_IID")


# Create a figure with two subplots
plt.figure(figsize=(10, 5))
x = np.arange(0, 82)
x_DONE = np.arange(0, 2 * 41, 2)
xlim = 41
print(rs_glob_acc_sop[:80].shape)
# Subplot 1: Training Accuracy
plt.subplot(1, 2, 1)
plt.plot(x[:80], rs_glob_acc_sop[:80], label='FedSophia', linestyle='--', marker='o', markevery=4)
plt.plot(x_DONE, rs_glob_acc_done, label='DONE', linestyle='--', marker='s', markevery=4)
plt.plot(x, rs_glob_acc_gd, label='FedAVG', linestyle='--', marker='D', markevery=4)

plt.title('Test Accuracy')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()

# Subplot 2: Training Loss
plt.subplot(1, 2, 2)
plt.plot(x[:80], rs_train_loss_sop[:80], label='FedSophia', linestyle='--', marker='o', markevery=4)
plt.plot(x_DONE, rs_train_loss_done, label='DONE', linestyle='--', marker='s', markevery=4)
plt.plot(x, rs_train_loss_gd, label='FedAVG', linestyle='--', marker='D', markevery=4)

plt.title('Training Loss')
plt.xlabel('Communication Rounds')
plt.ylabel('Loss')
plt.legend()

plt.savefig('Mnist_MLP_.eps', format='eps')

plt.tight_layout()
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Mnist_Sophia_0.01_(0.9, 0.95)_5.0_0.1_32u_64b_1_0_IID
# Mnist_DONE_1_0.01_1.0_0.001_32u_0b_40_0_IID
# Mnist_FedAvg_0.008_0.03_20.0_0.001_32u_64b_10_0_IID
# (80,)

# %%
a = rs_train_acc_sop

# %% [markdown]
# # MNIST NIID

# %%
rs_train_acc_sop, rs_train_loss_sop, rs_glob_acc_sop = simple_read_data("Mnist_Sophia_0.01_(0.9, 0.95)_5.0_0.1_32u_64b_1_0_NIID")
rs_train_acc_done, rs_train_loss_done, rs_glob_acc_done = simple_read_data("Mnist_DONE_1_0.004_1.0_0.001_32u_0b_80_0_NIID")
#("Mnist_DONE_1_0.008_1.0_0.001_32u_0b_40_0")
rs_train_acc_gd, rs_train_loss_gd, rs_glob_acc_gd = simple_read_data("Mnist_FedAvg_0.008_0.03_20.0_0.001_32u_64b_10_0_NIID")


# Create a figure with two subplots
plt.figure(figsize=(10, 5))
x = np.arange(0, 82)
x_DONE = np.arange(0, 2 * 41, 2)
xlim = 41
print(rs_glob_acc_sop[:80].shape)
# Subplot 1: Training Accuracy
plt.subplot(1, 2, 1)
plt.plot(x[:80], rs_glob_acc_sop[:80], label='FedSophia', linestyle='--', marker='o', markevery=4)
plt.plot(x_DONE, rs_glob_acc_done, label='DONE', linestyle='--', marker='s', markevery=4)
plt.plot(x, rs_glob_acc_gd, label='FedAVG', linestyle='--', marker='D', markevery=4)

plt.title('Test Accuracy')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()

# Subplot 2: Training Loss
plt.subplot(1, 2, 2)
plt.plot(x[:80], rs_train_loss_sop[:80], label='FedSophia', linestyle='--', marker='o', markevery=4)
plt.plot(x_DONE, rs_train_loss_done, label='DONE', linestyle='--', marker='s', markevery=4)
plt.plot(x, rs_train_loss_gd, label='FedAVG', linestyle='--', marker='D', markevery=4)

plt.title('Training Loss')
plt.xlabel('Communication Rounds')
plt.ylabel('Loss')
plt.legend()

plt.savefig('Mnist_MLP_.eps', format='eps')

plt.tight_layout()
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Mnist_Sophia_0.01_(0.9, 0.95)_5.0_0.1_32u_64b_1_0_NIID
# Mnist_DONE_1_0.004_1.0_0.001_32u_0b_80_0_NIID
# Mnist_FedAvg_0.008_0.03_20.0_0.001_32u_64b_10_0_NIID
# (80,)

# %%
b = rs_train_acc_sop

a[-1] - b[-1]
# Out:
# 0.0

# %%
x_DONE = np.load('./NIID_times/DONE_time.npy')
x_FedAvg = np.load('./NIID_times/Fed_AVG_time.npy')
x_Sophia = np.load('./NIID_times/Sophia_time.npy')
x_DONE /= 32 / 1000
x_FedAvg /= 32 / 1000
x_Sophia /= 32 / 1000

# %% [markdown]
# # MNIST NIID CPU Time

# %%
rs_train_acc_sop, rs_train_loss_sop, rs_glob_acc_sop = simple_read_data("Mnist_Sophia_0.01_(0.9, 0.95)_5.0_0.1_32u_64b_1_0_IID")
rs_train_acc_done, rs_train_loss_done, rs_glob_acc_done = simple_read_data("Mnist_DONE_1_0.004_1.0_0.001_32u_0b_80_0_NIID")
#("Mnist_DONE_1_0.008_1.0_0.001_32u_0b_40_0")
rs_train_acc_gd, rs_train_loss_gd, rs_glob_acc_gd = simple_read_data("Mnist_FedAvg_0.008_0.03_20.0_0.001_32u_64b_10_0_NIID")


# Create a figure with two subplots
plt.figure(figsize=(10, 5))

xlim_soph = 81
xlim_fedavg = 41
xlim_done = 5
print(rs_glob_acc_sop[:80].shape)
# Subplot 1: Training Accuracy
plt.subplot(1, 2, 1)
plt.plot(x_Sophia[:xlim_soph], rs_glob_acc_sop[:xlim_soph], label='FedSophia', linestyle='--', marker='o', markevery=4)
plt.plot(x_DONE[:xlim_done], rs_glob_acc_done[:xlim_done], label='DONE', linestyle='--', marker='s', markevery=4)
plt.plot(x_FedAvg[:xlim_fedavg], rs_glob_acc_gd[:xlim_fedavg], label='FedAVG', linestyle='--', marker='D', markevery=4)

plt.title('Test Accuracy')
plt.xlabel('CPU Time [ms]')
plt.ylabel('Accuracy')
plt.legend()

# Subplot 2: Training Loss
plt.subplot(1, 2, 2)
plt.plot(x_Sophia[:xlim_soph], rs_train_loss_sop[:xlim_soph], label='FedSophia', linestyle='--', marker='o', markevery=4)
plt.plot(x_DONE[:xlim_done], rs_train_loss_done[:xlim_done], label='DONE', linestyle='--', marker='s', markevery=4)
plt.plot(x_FedAvg[:xlim_fedavg], rs_train_loss_gd[:xlim_fedavg], label='FedAVG', linestyle='--', marker='D', markevery=4)

plt.title('Training Loss')
plt.xlabel('CPU Time [ms]')
plt.ylabel('Loss')
plt.legend()

plt.savefig('Mnist_MLP_.eps', format='eps')

plt.tight_layout()
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Mnist_Sophia_0.01_(0.9, 0.95)_5.0_0.1_32u_64b_1_0_IID
# Mnist_DONE_1_0.01_1.0_0.001_32u_0b_40_0_IID
# Mnist_FedAvg_0.008_0.03_20.0_0.001_32u_64b_10_0_IID
# (80,)

# %% [markdown]
# # CIFAR-10 NIID

# %%
rs_train_acc_sop, rs_train_loss_sop, rs_glob_acc_sop = simple_read_data("Cifar10_Sophia_0.001_(0.9, 0.95)_20.0_0.1_20u_64b_1_0_IID")
#rs_train_acc_done, rs_train_loss_done, rs_glob_acc_done = simple_read_data("Mnist_DONE_1_0.003_1.0_0.001_32u_0b_40_0")
#("Mnist_DONE_1_0.008_1.0_0.001_32u_0b_40_0")
rs_train_acc_gd, rs_train_loss_gd, rs_glob_acc_gd = simple_read_data("Cifar10_FedAvg_0.01_0.03_20.0_0.001_20u_64b_10_0_IID")


import matplotlib.pyplot as plt
import numpy as np

# Create a figure with two subplots
plt.figure(figsize=(10, 5))
x = np.arange(0, 300)
x_DONE = np.arange(0, 2 * 41, 2)
xlim = 41
print(rs_glob_acc_sop[:80].shape)
# Subplot 1: Training Accuracy
plt.subplot(1, 2, 1)
plt.plot(x[:299], rs_glob_acc_sop[0:299], label='FedSophia', linestyle='--', marker='o', markevery=20)
#plt.plot(x_DONE, rs_glob_acc_done, label='DONE', linestyle='--', marker='s', markevery=4)
plt.plot(x[:299], rs_glob_acc_gd[0:299], label='FedAVG', linestyle='--', marker='D', markevery=20)

plt.title('Test Accuracy')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()

# Subplot 2: Training Loss
plt.subplot(1, 2, 2)
plt.plot(x[:299], rs_train_loss_sop[0:299], label='FedSophia', linestyle='--', marker='o', markevery=20)
#plt.plot(x_DONE, rs_train_loss_done, label='DONE', linestyle='--', marker='s', markevery=4)
plt.plot(x[:299], rs_train_loss_gd[0:299], label='FedAVG', linestyle='--', marker='D', markevery=20)

plt.title('Training Loss')
plt.xlabel('Communication Rounds')
plt.ylabel('Loss')
plt.legend()

plt.savefig('Mnist_MLP_.eps', format='eps')

plt.tight_layout()
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Cifar10_Sophia_0.001_(0.9, 0.95)_20.0_0.1_20u_64b_1_0_IID
# Cifar10_FedAvg_0.01_0.03_20.0_0.001_20u_64b_10_0_IID
# (80,)

# %% [markdown]
# # CIFAR-10 NIID

# %%
rs_train_acc_sop, rs_train_loss_sop, rs_glob_acc_sop = simple_read_data("Cifar10_Sophia_0.001_(0.9, 0.95)_20.0_0.1_20u_64b_1_0_NIID")
#rs_train_acc_done, rs_train_loss_done, rs_glob_acc_done = simple_read_data("Mnist_DONE_1_0.003_1.0_0.001_32u_0b_40_0")
#("Mnist_DONE_1_0.008_1.0_0.001_32u_0b_40_0")
rs_train_acc_gd, rs_train_loss_gd, rs_glob_acc_gd = simple_read_data("Cifar10_FedAvg_0.01_0.03_20.0_0.001_20u_64b_10_0_NIID")


import matplotlib.pyplot as plt
import numpy as np

# Create a figure with two subplots
plt.figure(figsize=(10, 5))
x = np.arange(0, 300)
x_DONE = np.arange(0, 2 * 41, 2)
xlim = 41
print(rs_glob_acc_sop[:80].shape)
# Subplot 1: Training Accuracy
plt.subplot(1, 2, 1)
plt.plot(x[:299], rs_glob_acc_sop[0:299], label='FedSophia', linestyle='--', marker='o', markevery=20)
#plt.plot(x_DONE, rs_glob_acc_done, label='DONE', linestyle='--', marker='s', markevery=4)
plt.plot(x[:299], rs_glob_acc_gd[0:299], label='FedAVG', linestyle='--', marker='D', markevery=20)

plt.title('Test Accuracy')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()

# Subplot 2: Training Loss
plt.subplot(1, 2, 2)
plt.plot(x[:299], rs_train_loss_sop[0:299], label='FedSophia', linestyle='--', marker='o', markevery=20)
#plt.plot(x_DONE, rs_train_loss_done, label='DONE', linestyle='--', marker='s', markevery=4)
plt.plot(x[:299], rs_train_loss_gd[0:299], label='FedAVG', linestyle='--', marker='D', markevery=20)

plt.title('Training Loss')
plt.xlabel('Communication Rounds')
plt.ylabel('Loss')
plt.legend()

plt.savefig('Mnist_MLP_.eps', format='eps')

plt.tight_layout()
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Cifar10_Sophia_0.001_(0.9, 0.95)_20.0_0.1_20u_64b_1_0_NIID
# Cifar10_FedAvg_0.01_0.03_20.0_0.001_20u_64b_10_0_NIID
# (80,)

# %%
# Finding the x scale 
from algorithms.trainmodel.models import *
model = Net()

num_params = sum([p.numel() for p in model.parameters()])


x_sophia = [0]
x_sophia_ota = [0]
x_fedavg = [0]
x_done = [0]
for i in range(rs_train_acc_sop.shape[0]):
    x_sophia.append(x_sophia[-1] + num_params * 32)
    
for i in range(rs_train_acc_sopota.shape[0]):
    x_sophia_ota.append(x_sophia_ota[-1] + num_params)
    
for i in range(rs_train_acc_gd.shape[0]):
    x_fedavg.append(x_fedavg[-1] + num_params * 32)
    
for i in range(rs_train_acc_done.shape[0]):
    x_done.append(x_done[-1] + num_params * 32 * 2)

# %% [markdown]
# # OTA MNIST

# %%
# Sopgia with SNRs

from utils.plot_utils import get_training_data_value, simple_read_data
import matplotlib.pyplot as plt
import numpy as np
rs_train_acc_sopota, rs_train_loss_sopota, rs_glob_acc_sopota = simple_read_data("Mnist_Sophia_OTA_0.01_(0.9, 0.95)_20.0_0.001_32u_64b_1_0")
rs_train_acc_sop, rs_train_loss_sop, rs_glob_acc_sop = simple_read_data("Mnist_Sophia_0.01_(0.9, 0.95)_20.0_0.001_32u_64b_1_0")
rs_train_acc_gd, rs_train_loss_gd, rs_glob_acc_gd = simple_read_data("Mnist_GD_0.01_0.03_20.0_0.001_30u_64b_1_0")
rs_train_acc_done, rs_train_loss_done, rs_glob_acc_done = simple_read_data("Mnist_DONE_1_0.003_1.0_0.001_32u_0b_40_0")


# Create a figure with two subplots
plt.figure(figsize=(10, 5))
x = np.arange(0, 82)
x_DONE = np.arange(0, 2 * 41, 2)
xlim = 41

# Subplot 1: Testing Accuracy
plt.subplot(1, 2, 1)
plt.plot(x_sophia[1:], rs_glob_acc_sop, label='FedSophia', linestyle='--', marker='o', markevery=4)
plt.plot(x_sophia_ota[1:], rs_glob_acc_sopota, label='OTA-FedSophia', linestyle='--', marker='s', markevery=100)
plt.plot(x_fedavg[1:], rs_glob_acc_gd, label='FedAvg', linestyle='--', marker='D', markevery=4)
plt.plot(x_done[1:], rs_glob_acc_done, label='Done', linestyle='--', marker='D', markevery=4)


plt.title('Test Accuracy')
plt.xlabel('Number of Uploads')
plt.ylabel('Accuracy')
plt.legend()

# Subplot 2: Training Loss
plt.subplot(1, 2, 2)
plt.plot(x_sophia[1:], rs_train_loss_sop, label='FedSophia', linestyle='--', marker='o', markevery=4)
plt.plot(x_sophia_ota[1:], rs_train_loss_sopota, label='OTA-FedSophia', linestyle='--', marker='s', markevery=100)
plt.plot(x_fedavg[1:], rs_train_loss_gd, label='FedAvg', linestyle='--', marker='D', markevery=4)
plt.plot(x_done[1:], rs_train_loss_done, label='Done', linestyle='--', marker='D', markevery=4)

plt.title('Training Loss')
plt.xlabel('Number of Uploads')
plt.ylabel('Loss')
plt.legend()

plt.savefig('Mnist_MLP_.eps', format='eps')

plt.tight_layout()
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Mnist_Sophia_OTA_0.01_(0.9, 0.95)_20.0_0.001_32u_64b_1_0
# Mnist_Sophia_0.01_(0.9, 0.95)_20.0_0.001_32u_64b_1_0
# Mnist_GD_0.01_0.03_20.0_0.001_30u_64b_1_0
# Mnist_DONE_1_0.003_1.0_0.001_32u_0b_40_0
